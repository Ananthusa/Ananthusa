# %%
# !git clone https://github.com/cbailes/awesome-ai-cardiology.git

# %%
# !git clone https://github.com/VenkateshBH99/Heart-and-Kidney-disease-prediction-Django.git

# %%
# !git clone https://github.com/kanchitank/Medibuddy-Smart-Disease-Predictor.git

# %%
# !git clone https://github.com/Projects-Developer/Heart-Diseases-Prediction-Project.git

# %%
# !git clone https://github.com/asthasharma98/Heart-Disease-Prediction-Deployment.git

# %%
# !git clone https://github.com/poloclub/CardiacAR.git

# %%
# !git clone https://github.com/MohamedAliHabib/Brain-Tumor-Detection.git

# %%
# !git clone https://github.com/aksh-ai/neuralBlack.git

# %%
# https://github.com/dheerajnbhat/Brain-Tumor-Detection.git

# %%
# !git clone https://github.com/princeedey/BRAIN-TUMOR-DETECTION-AND-SEGMENTATION-USING-MRI-IMAGES.git

# %%
# https://github.com/surgical-robotics-ai/SurgicAI.git

# %%
# !git clone https://github.com/surgical-robotics-ai/surgical_robotics_challenge.git

# %%
# !git clone https://github.com/dreamingechoes/awesome-mental-health.git

# %%
# !git clone https://github.com/Flaque/quirk.git

# %%
# !git clone https://github.com/AiCompendium/Ethical-AI-Framework.git

# %%
# !git clone https://github.com/elder-plinius/CL4R1T4S.git

# %%
# !git clone https://github.com/ModelDBRepository/229276.git

# %%
#literally 7 emotions have human
#learn more about emotions

# %%
# !git https://github.com/kartikgupta-at-anu/md-bnn.git

# %%
# !git clone https://github.com/surgical-robotics-ai/SurgicAI.git

# %%
# !git clone https://github.com/CAMMA-public/AI4surgery.git

# %%
# !git clone https://github.com/abhi3940/HTM-4.0.git
